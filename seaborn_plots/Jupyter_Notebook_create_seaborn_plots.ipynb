# %%
import sys
import joblib
import pandas as pd 
import numpy as np
import scipy.io
from scipy.io import loadmat
#from sklearn.model_selection import train_test_split, StratifiedKFold
#from sklearn.utils import parallel_backend
#from julearn import run_cross_validation
import seaborn as sns
import julearn
import matplotlib.colors as mcolors
import matplotlib.patches as mpatch

# %%
# define paths
Path_2_merged_tables = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/Code_sample_description_results_computations_LW_local_calibrated_predictions/03_merged_results_overview_tables'
#Path_2_merged_tables = '/data/project/transgender_replication/Code_sample_description_results_computations_LW_calibrated_predictions/03_merged_results_overview_tables'

savedir = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/seaborn_plots'
#savedir = '/data/project/transgender_replication/Code_sample_description_results_computations_LW_calibrated_predictions/seaborn_plots'


### test samples
list_samplenames = ['val-age_calibrated_predictions_model_trained_on_confound-None_sample-age',
                    'val-age_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                    'val-age_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                    'val-age_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                    
                    'val-ageTIV_calibrated_predictions_model_trained_on_confound-None_sample-age',
                    'val-ageTIV_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                    'val-ageTIV_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                    'val-ageTIV_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                   ]


# define color palette:
palette = ['tab:red', 'tab:blue']

# iterate through all datanames to create plot for each model x sample:
for i in range(8):
    dataname = list_samplenames[i]
    
    datatable = pd.read_csv(f'{Path_2_merged_tables}/merged_table_{dataname}.csv')
    sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.png')
    #sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.jpg')
    
    #sns_kde_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", kind = "kde", palette = palette, xlim = [0, 1]) 
    #sns_kde_plot.savefig(f'{savedir}/{dataname}_seaborn_kde_plot.png')
sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.png')
#sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.jpg')

# %%
### application samples:
list_samplenames_application_samples = [                    
                                        'aachen_calibrated_predictions_model_trained_on_confound-None_sample-age',
                                        'aachen_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                                        'aachen_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                                        'aachen_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                        
                                        'barcelona_calibrated_predictions_model_trained_on_confound-None_sample-age',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV'
                                           ]


palette = ['tab:blue', 'tab:red', 'tab:orange', 'tab:cyan']

# iterate through all datanames to create plot for each model x sample:
for i in range(8):
    dataname = list_samplenames_application_samples[i]
    
    datatable = pd.read_csv(f'{Path_2_merged_tables}/merged_table_{dataname}.csv')
    sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.png')
    #sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.jpg')
   

sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.png')
#sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.png')

# %%
### plots for merged test samples:

# define paths
Path_2_merged_tables = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/Code_sample_description_results_computations_LW_local_calibrated_predictions/03_merged_results_overview_tables/merged_test_samples'

savedir = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/seaborn_plots/plots_merged_test_samples'

list_samplenames = [
                    'merged_table_AM_ATM_test_sample_calibrated_predictions_model_trained_on_confound-None_sample-age',
                    'merged_table_AM_ATM_test_sample_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                    'merged_table_AM_ATM_test_sample_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                    'merged_table_AM_ATM_test_sample_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                    ]

# define color palette:
palette = ['tab:red', 'tab:blue']

# iterate through all datanames to create plot for each model x sample:
for i in range(4):
    dataname = list_samplenames[i]
    
    datatable = pd.read_csv(f'{Path_2_merged_tables}/{dataname}.csv')
    sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.png')
    #sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.jpg')
    
    #sns_kde_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", kind = "kde", palette = palette, xlim = [0, 1]) 
    #sns_kde_plot.savefig(f'{savedir}/{dataname}_seaborn_kde_plot.png')
sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.png')
#sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.jpg')

# %%
### plots for merged application samples

# define paths
Path_2_merged_tables = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/Code_sample_description_results_computations_LW_local_calibrated_predictions/03_merged_results_overview_tables/merged_application_samples'

savedir = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/seaborn_plots/plots_merged_application_samples'

list_samplenames = [
                    'merged_table_application_samples_calibrated_predictions_model_trained_on_confound-None_sample-age',
                    'merged_table_application_samples_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                    'merged_table_application_samples_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                    'merged_table_application_samples_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                    ]

palette = ['tab:blue', 'tab:red', 'tab:orange', 'tab:cyan']

for i in range(4):
    dataname = list_samplenames[i]
    
    datatable = pd.read_csv(f'{Path_2_merged_tables}/{dataname}.csv')
    sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.png')
    #sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot.jpg')
    
    #sns_kde_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "sex", kind = "kde", palette = palette, xlim = [0, 1]) 
    #sns_kde_plot.savefig(f'{savedir}/{dataname}_seaborn_kde_plot.png')
sns_plot = sns.jointplot(data = datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette, xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.png')
#sns_plot.savefig(f'{savedir}/{dataname}_seaborn_plot_with_legend.jpg')

# %%
### plots for merged application samples

# define paths
Path_2_merged_tables = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/Code_sample_description_results_computations_LW_local_calibrated_predictions/03_merged_results_overview_tables/separate_cis_trans_tables_application_samples'

savedir = '/Users/lwiersch/Desktop/Lisa_PhD_INM7/replication_project_transgender_paper/seaborn_plots/separate_cis_transgender_plots'

### application samples:
list_samplenames_application_samples = [                    
                                        'aachen_calibrated_predictions_model_trained_on_confound-None_sample-age',
                                        'aachen_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                                        'aachen_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                                        'aachen_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV',
                        
                                        'barcelona_calibrated_predictions_model_trained_on_confound-None_sample-age',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-TIV_sample-age',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-None_sample-age_TIV',
                                        'barcelona_calibrated_predictions_model_trained_on_confound-TIV_sample-age_TIV'
                                           ]

# %%
# cisgender plots:
palette = ['tab:blue', 'tab:red']

for i in range(8):
    dataname = list_samplenames_application_samples[i]
    
    # cisgender plot:
    cis_datatable = pd.read_csv(f'{Path_2_merged_tables}/cisgender_table_{dataname}.csv')
    sns_plot = sns.jointplot(data = cis_datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/cisgender_{dataname}_seaborn_plot.png')
    
sns_plot = sns.jointplot(data = cis_datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/cisgender_{dataname}_seaborn_plot_with_legend.png')

# %%
# transgender plots:
palette = ['tab:orange', 'tab:cyan']

for i in range(8):
    dataname = list_samplenames_application_samples[i]
    
    # transgender plot:
    trans_datatable = pd.read_csv(f'{Path_2_merged_tables}/transgender_table_{dataname}.csv')
    sns_plot = sns.jointplot(data = trans_datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960], legend = False)  
    sns_plot.refline(x = 0.5, color = "grey")
    sns_plot.savefig(f'{savedir}/transgender_{dataname}_seaborn_plot.png')
    
sns_plot = sns.jointplot(data = trans_datatable, x = "pred_proba_0", y = "TIV", hue = "group", palette = palette ,xlim = [-0.02, 1.01], ylim = [1010, 1960])  
sns_plot.savefig(f'{savedir}/transgender{dataname}_seaborn_plot_with_legend.png')


#palette = ['tab:blue', 'tab:red', 'tab:orange', 'tab:cyan']
